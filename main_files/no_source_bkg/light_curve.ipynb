# %%
from astropy.time import Time
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt

from pyspi.utils.data_builder.time_series_builder import TimeSeriesBuilderSPI
# Out:
# 10:55:38 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=576095;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=331043;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#48\48]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=963527;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=38199;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#69\69]8;;\
#                   will not be available.
# ...

# %% [markdown]
# ## Plot all dets of a pointing

# %%
with fits.open("/home/tguethle/cookbook/SPI_cookbook/examples/automated_Crab/dataset_skymap374-3/spi/evts_det_spec.fits.gz") as hdul:
    hdul.info()
    counts = hdul[1].data["COUNTS"]


counts.shape # (pointings_nr * dets, energy_bins_nr)

with fits.open("/home/tguethle/cookbook/SPI_cookbook/examples/automated_Crab/dataset_skymap374-3/spi/dead_time.fits.gz") as hdul:
    hdul.info()
    time = hdul[1].data['LIVETIME']

time.shape # (pointings_nr * dets, )
# Out:
# Filename: /home/tguethle/cookbook/SPI_cookbook/examples/automated_Crab/dataset_skymap374-3/spi/evts_det_spec.fits.gz
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  SPI.-OBS.-DSP    1 BinTableHDU     80   779R x 2C   [41J, 41E]
# Filename: /home/tguethle/cookbook/SPI_cookbook/examples/automated_Crab/dataset_skymap374-3/spi/dead_time.fits.gz
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  SPI.-OBS.-DTI    1 BinTableHDU     73   779R x 2C   [1E, 1D]
# (779,)

# %%
det = 4
counts_0 = counts[det::19]
total_counts = np.sum(counts_0, axis=1)
time_per_det = time[det::19]
normal_counts = total_counts / time_per_det
plt.plot(normal_counts)

# %% [markdown]
# ### sum over all dets

# %%
time[time == 0] = 1
all_E_counts = np.sum(counts, axis=1) / time
print(all_E_counts.shape)
assert all_E_counts.shape[0] % 19 == 0
all_E_counts = all_E_counts.reshape(-1, 19).sum(axis=1)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(all_E_counts)
ax.set_xlabel("Time bzw. Pointing")
ax.set_ylabel("Counts / s (all energies and all detectors)")


ax.grid()
# Out:
# (779,)

# %% [markdown]
# there seem to be more counts than average in pointing 3... also in pointing 14 but only half the height.

# %%
all_E_counts.shape
# Out:
# (41,)

# %%
with fits.open("/home/tguethle/cookbook/SPI_cookbook/examples/automated_Crab/dataset_skymap374-3/spi/pointing.fits.gz") as hdul:
    hdul.info()
    pointings = hdul[1].data

pointings["PTID_ISOC"].shape
# Out:
# Filename: /home/tguethle/cookbook/SPI_cookbook/examples/automated_Crab/dataset_skymap374-3/spi/pointing.fits.gz
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  SPI.-OBS.-PNT    1 BinTableHDU     99   41R x 11C   [8A, 15A, 4I, 4I, 1D, 1D, 1D, 1E, 1E, 1E, 1E]
# (41,)

# %% [markdown]
# ## Via pyspi (does not seem to work with the required pointings)

# %%
from pyspi.utils.data_builder.time_series_builder import TimeSeriesBuilderSPI


grbtime = Time('2005-11-05T08:30:00', format='isot', scale='utc')

ebounds = np.geomspace(20, 600, 2)


det = 0
# tsb = TimeSeriesBuilderSPI.from_spi_grb(f"SPIDet{det}",
#                                         det,
#                                         grbtime,
#                                         ebounds=ebounds,
#                                         sgl_type="both",
#                                        )

tsb2 = TimeSeriesBuilderSPI.from_spi_constant_pointing(det, pointing_id='037400050010', ebounds=ebounds)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [2], in <cell line: 17>()
#       9 det = 0
#      10 # tsb = TimeSeriesBuilderSPI.from_spi_grb(f"SPIDet{det}",
#      11 #                                         det,
#      12 #                                         grbtime,
#      13 #                                         ebounds=ebounds,
#      14 #                                         sgl_type="both",
#      15 #                                        )
# ---> 17 tsb2 = TimeSeriesBuilderSPI.from_spi_constant_pointing(det, pointing_id='037400050010', ebounds=ebounds)
#
# File ~/.opt/conda/envs/spi39/lib/python3.9/site-packages/pyspi/utils/data_builder/time_series_builder.py:856, in TimeSeriesBuilderSPI.from_spi_constant_pointing(cls, det, pointing_id, ebounds, response)
#     852 elif response is not None:
#     853     # ebounds is None in this case
# ...

# %%
fig = tsb.view_lightcurve()

# %%
fig.savefig("lightcurve.png")

# %%
with fits.open("/home/tguethle/Documents/spi/pyspi_external_data/pointing_data/118900580010/spi_oper.fits.gz") as hdul:
    
    hdul.info()
    d = hdul[1].data
    print(sum(d['ENERGY']))

# %%
d

# %%
sum(d['ENERGY'])
