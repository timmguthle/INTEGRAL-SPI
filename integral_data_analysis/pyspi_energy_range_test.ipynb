# %%
from pyspi.utils.data_builder.time_series_builder import TimeSeriesBuilderSPI
import numpy as np
from pyspi.utils.function_utils import find_response_version
from pyspi.utils.response.spi_response_data import ResponseDataRMF
from pyspi.utils.response.spi_response import ResponseRMFGenerator
from pyspi.utils.response.spi_drm import SPIDRM
from pyspi.utils.livedets import get_live_dets

grb_time = "120711 024453"
ebounds = np.geomspace(20,80,40)
ein = np.geomspace(10,3000,50)
t1 = 35000
t2 = 38000
version = find_response_version(grb_time)
rsp_base = ResponseDataRMF.from_version(version)
dets = get_live_dets(time=grb_time, event_types=["single"])
# Out:
# 14:19:59 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=72116;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=183141;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#48\48]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=825171;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=348103;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#69\69]8;;\
#                   will not be available.
# 14:20:00 WARNING   The ebltable package is not available. Models that depend on it will not be     ]8;id=3812;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/astromodels/functions/functions_1D/absorption.py\absorption.py]8;;\:]8;id=813767;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/astromodels/functions/functions_1D/absorption.py#33\33]8;;\
#                   available
# 14:20:00 INFO      Starting 3ML!                                                                     ]8;id=508064;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=849186;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/__init__.py#31\31]8;;\
# 14:20:02 WARNING   ROOT minimizer not available                                                ]8;id=155102;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=257871;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/minimizer/minimization.py#1345\1345]8;;\
# 14:20:03 WARNING   PyGMO is not available                                                      ]8;id=731343;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=91238;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/minimizer/minimization.py#1369\1369]8;;\
# 14:20:03 WARNING   The cthreeML package is not installed. You will not be able to use plugins which  ]8;id=869757;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=220376;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/__init__.py#79\79]8;;\
#                   require the C/C++ interface (currently HAWC)
#          WARNING   Could not import plugin HAWCLike.py. Do you have the relative instrument         ]8;id=561248;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=832256;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/__init__.py#129\129]8;;\
#                   software installed and configured?
#          WARNING   Could not import plugin FermiLATLike.py. Do you have the relative instrument     ]8;id=234265;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=423523;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/__init__.py#129\129]8;;\
#                   software installed and configured?
# 14:20:04 WARNING   No fermitools installed                                              ]8;id=989779;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py\lat_transient_builder.py]8;;\:]8;id=692619;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py#44\44]8;;\
# 14:20:04 WARNING   Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=358332;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=203639;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/__init__.py#341\341]8;;\
#                   performances in 3ML
#          WARNING   Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=317610;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=234373;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/__init__.py#341\341]8;;\
#                   performances in 3ML
#          WARNING   Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal     ]8;id=49770;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=931527;file:///home/tguethle/.opt/conda/envs/spi39/lib/python3.9/site-packages/threeML/__init__.py#341\341]8;;\
#                   performances in 3ML
# Using the irfs that are valid between 10/05/27 12:45:00 and present (YY/MM/DD HH:MM:SS)

# %%
tsbs = []
sds1 = []
sds2 = []
ra1, dec1 = 94.67830, -70.99905
ra2, dec2 = 92.67830, -70.99905
for d in dets:
    tsb = TimeSeriesBuilderSPI.from_spi_grb(f"SPIDet{d}", 
                                        d, 
                                        #ebounds_sgl, 
                                        grb_time, 
                                        ebounds=ebounds,
                                        sgl_type="both",
                                        poly_order=-1,
                                        )
    rsp = ResponseRMFGenerator.from_time(grb_time,  d,
                                            ebounds, ein,
                                            rsp_base)
    sd1 = SPIDRM(rsp, ra1, dec1)
    sd2 = SPIDRM(rsp.clone(), ra2, dec2)
    tsbs.append(tsb)
    sds1.append(sd1)
    sds2.append(sd2)

# %%
bkgs=np.array([])
for tsb in tsbs:
    bkgs = np.append(bkgs, tsb.time_series.count_per_channel_over_interval(-1000,0)/tsb.time_series.exposure_over_interval(-1000,0))
bkgs=bkgs.reshape((len(dets), -1));

# %%
# source model
from astromodels import Powerlaw, Log_uniform_prior, Uniform_prior, PointSource, SpectralComponent
import numpy as np
pl = Powerlaw()
pl.index = -2.08
pl.K = 6.44*10**-4
pl.piv = 100

pl.K.prior = Log_uniform_prior(lower_bound=1e-8, upper_bound=1e0)
pl.index.prior = Uniform_prior(lower_bound=-4, upper_bound=0)

component1 = SpectralComponent('pl',shape=pl)
ps = PointSource('plline',ra=94.67830, dec=-70.99905, components=[component1])

spec = ps(ein)

spec_binned = (ein[1:]-ein[:-1])*(spec[:-1]+spec[1:])/2

# %%
# model counts
model_count_rates1 = np.array([])#np.dot(spec_binned, sd_sgl1.matrix.T)
model_count_rates2 = np.array([])#np.dot(spec_binned, sd_sgl2.matrix.T)
for sd1, sd2 in zip(sds1, sds2):
    model_count_rates1 = np.append(model_count_rates1, np.dot(spec_binned, sd1.matrix.T))
    model_count_rates2 = np.append(model_count_rates2, np.dot(spec_binned, sd2.matrix.T))
model_count_rates1 = model_count_rates1.reshape((len(dets), -1));
model_count_rates2 = model_count_rates2.reshape((len(dets), -1));

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(5,4, sharex=True, sharey=True, figsize=(10,10))
axes = axes.flatten()
i=0
for d in range(19):
    axes[d].text(.5,.9,f"Det {d}",horizontalalignment='center',transform=axes[d].transAxes)
    if d in dets:
        if i==0:
            axes[d].step(ebounds[:-1], bkgs[i], label="background")
            axes[d].step(ebounds[:-1], model_count_rates1[i], label="model1")
            axes[d].step(ebounds[:-1], model_count_rates2[i], label="model2")
        else:
            axes[d].step(ebounds[:-1], bkgs[i])
            axes[d].step(ebounds[:-1], model_count_rates1[i])
            axes[d].step(ebounds[:-1], model_count_rates2[i])
        i+=1
    axes[d].set_yscale("log")
    axes[d].set_ylim(10**-3, 20)
for i in range(16,20):
    axes[i].set_xlabel("Detected Energy [keV]")
for i in range(0,20,4):
    axes[i].set_ylabel("Count Rates [1/s]")
plt.subplots_adjust(hspace=0, wspace=0)
plt.subplots_adjust(hspace=0, top=0.96, bottom=0.1)
lgd = fig.legend(loc='center left', bbox_to_anchor=(0.9, 0.5), fontsize='x-large')
# fig.savefig("bkg_models.pdf")

# %%
data1 = np.array([])
data2 = np.array([])
for bkg, m1, m2 in zip(bkgs, model_count_rates1, model_count_rates2):
    data1 = np.append(data1, np.random.poisson(t1*(bkg+m1)))
    data2 = np.append(data2, np.random.poisson(t2*(bkg+m2)))
    
data1 = data1.reshape((len(dets), -1));
data2 = data2.reshape((len(dets), -1));

# %%
import math
from numba import njit

@njit
def bmaxba(m1, m2, t1, t2, C1, C2):
    first = C1+C2-(m1+m2)*(t1+t2)
    root = (C1+C2+(m1-m2)*(t1+t2))**2-4*C1*(m1-m2)*(t1+t2)
    res = (first+np.sqrt(root))/(2*(t1+t2))
    return res
matrices1 = np.array([])
sd_x, sd_y = sds1[0].matrix.T.shape
for sd in sds1:
    matrices1=np.append(matrices1,sd.matrix.T)
matrices1=matrices1.reshape((len(dets), sd_x, sd_y))

matrices2 = np.array([])
for sd in sds2:
    matrices2=np.append(matrices2,sd.matrix.T)
matrices2=matrices2.reshape((len(dets), sd_x, sd_y))

@njit
def logLcore(spec_binned):
    logL=0
    for j in range(len(dets)):
        m1 = np.dot(spec_binned, matrices1[j])
        m2 = np.dot(spec_binned, matrices2[j])
        for i in range(len(m1)):
            bm = bmaxba(m1[i], m2[i], t1, t2, data1[j, i], data2[j, i])
            logL += (data1[j,i]*math.log(t1*(m1[i]+bm))+
                    data2[j,i]*math.log(t2*(m2[i]+bm))-
                    t1*(m1[i]+bm)-
                    t2*(m2[i]+bm))
    return logL

def logLba_mult(trial_values, ndim=None, params=None):
    pl.index = trial_values[1]
    pl.K = trial_values[0]
    spec = pl(ein)
    spec_binned = (ein[1:]-ein[:-1])*(spec[:-1]+spec[1:])/2
    return logLcore(spec_binned)

# %%
def prior(params, ndim=None, nparams=None):
    for i, (parameter_name, parameter) in enumerate(
        ps.free_parameters.items()
    ):

        try:

            params[i] = parameter.prior.from_unit_cube(params[i])

        except AttributeError:

            raise RuntimeError(
                "The prior you are trying to use for parameter %s is "
                "not compatible with sampling from a unitcube"
                % parameter_name
            )

# %%
import pymultinest
import os
if not os.path.exists("./chains"):
    os.mkdir("chains")
sampler = pymultinest.run(
                    logLba_mult, prior, 2, 2, n_live_points=800, resume=False, verbose=True
                )
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  800
#  dimensionality =    2
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.998825
# Replacements:                                850
# Total Samples:                               851
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999412
# Acceptance Rate:                        0.991189
# Replacements:                                900
# Total Samples:                               908
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999449
# Acceptance Rate:                        0.984456
# Replacements:                                950
# Total Samples:                               965
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999482
# Acceptance Rate:                        0.975610
# Replacements:                               1000
# Total Samples:                              1025
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999512
# Acceptance Rate:                        0.956284
# Replacements:                               1050
# Total Samples:                              1098
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999544
# Acceptance Rate:                        0.940171
# Replacements:                               1100
# Total Samples:                              1170
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999572
# Acceptance Rate:                        0.916335
# Replacements:                               1150
# Total Samples:                              1255
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999601
# Acceptance Rate:                        0.907716
# Replacements:                               1200
# Total Samples:                              1322
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999622
# Acceptance Rate:                        0.901876
# Replacements:                               1250
# Total Samples:                              1386
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999639
# Acceptance Rate:                        0.900277
# Replacements:                               1300
# Total Samples:                              1444
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999654
# Acceptance Rate:                        0.898204
# Replacements:                               1350
# Total Samples:                              1503
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999667
# Acceptance Rate:                        0.896287
# Replacements:                               1400
# Total Samples:                              1562
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999680
# Acceptance Rate:                        0.890117
# Replacements:                               1450
# Total Samples:                              1629
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999693
# Acceptance Rate:                        0.888626
# Replacements:                               1500
# Total Samples:                              1688
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999704
# Acceptance Rate:                        0.884199
# Replacements:                               1550
# Total Samples:                              1753
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999715
# Acceptance Rate:                        0.880088
# Replacements:                               1600
# Total Samples:                              1818
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999725
# Acceptance Rate:                        0.872554
# Replacements:                               1650
# Total Samples:                              1891
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999698
# Acceptance Rate:                        0.869565
# Replacements:                               1700
# Total Samples:                              1955
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999706
# Acceptance Rate:                        0.863345
# Replacements:                               1750
# Total Samples:                              2027
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999715
# Acceptance Rate:                        0.861656
# Replacements:                               1800
# Total Samples:                              2089
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999723
# Acceptance Rate:                        0.857673
# Replacements:                               1850
# Total Samples:                              2157
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.710953
# Acceptance Rate:                        0.855471
# Replacements:                               1900
# Total Samples:                              2221
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.710962
# Acceptance Rate:                        0.854514
# Replacements:                               1950
# Total Samples:                              2282
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.710970
# Acceptance Rate:                        0.851064
# Replacements:                               2000
# Total Samples:                              2350
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.710979
# Acceptance Rate:                        0.849213
# Replacements:                               2050
# Total Samples:                              2414
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.710986
# Acceptance Rate:                        0.846092
# Replacements:                               2100
# Total Samples:                              2482
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.710994
# Acceptance Rate:                        0.844130
# Replacements:                               2150
# Total Samples:                              2547
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.711000
# Acceptance Rate:                        0.841944
# Replacements:                               2200
# Total Samples:                              2613
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.711007
# Acceptance Rate:                        0.837365
# Replacements:                               2250
# Total Samples:                              2687
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.711014
# Acceptance Rate:                        0.834543
# Replacements:                               2300
# Total Samples:                              2756
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.711021
# Acceptance Rate:                        0.833629
# Replacements:                               2350
# Total Samples:                              2819
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.711026
# Acceptance Rate:                        0.831025
# Replacements:                               2400
# Total Samples:                              2888
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.711032
# Acceptance Rate:                        0.827144
# Replacements:                               2450
# Total Samples:                              2962
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.711038
# Acceptance Rate:                        0.823181
# Replacements:                               2500
# Total Samples:                              3037
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.711043
# Acceptance Rate:                        0.821521
# Replacements:                               2550
# Total Samples:                              3104
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.706031
# Acceptance Rate:                        0.818382
# Replacements:                               2600
# Total Samples:                              3177
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.705947
# Acceptance Rate:                        0.815887
# Replacements:                               2650
# Total Samples:                              3248
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.705951
# Acceptance Rate:                        0.815217
# Replacements:                               2700
# Total Samples:                              3312
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.700764
# Acceptance Rate:                        0.812648
# Replacements:                               2750
# Total Samples:                              3384
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.700769
# Acceptance Rate:                        0.812301
# Replacements:                               2800
# Total Samples:                              3447
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.700773
# Acceptance Rate:                        0.810811
# Replacements:                               2850
# Total Samples:                              3515
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.700776
# Acceptance Rate:                        0.810056
# Replacements:                               2900
# Total Samples:                              3580
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.700780
# Acceptance Rate:                        0.807334
# Replacements:                               2950
# Total Samples:                              3654
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.700784
# Acceptance Rate:                        0.807103
# Replacements:                               3000
# Total Samples:                              3717
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.700787
# Acceptance Rate:                        0.807519
# Replacements:                               3050
# Total Samples:                              3777
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.700790
# Acceptance Rate:                        0.803317
# Replacements:                               3100
# Total Samples:                              3859
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.682450
# Acceptance Rate:                        0.801323
# Replacements:                               3150
# Total Samples:                              3931
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.658786
# Acceptance Rate:                        0.798403
# Replacements:                               3200
# Total Samples:                              4008
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.655250
# Acceptance Rate:                        0.796764
# Replacements:                               3250
# Total Samples:                              4079
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.655253
# Acceptance Rate:                        0.792888
# Replacements:                               3300
# Total Samples:                              4162
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.655257
# Acceptance Rate:                        0.790654
# Replacements:                               3350
# Total Samples:                              4237
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.653505
# Acceptance Rate:                        0.788680
# Replacements:                               3400
# Total Samples:                              4311
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.653261
# Acceptance Rate:                        0.786773
# Replacements:                               3450
# Total Samples:                              4385
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.653264
# Acceptance Rate:                        0.786871
# Replacements:                               3500
# Total Samples:                              4448
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.653266
# Acceptance Rate:                        0.786791
# Replacements:                               3550
# Total Samples:                              4512
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.653269
# Acceptance Rate:                        0.787229
# Replacements:                               3600
# Total Samples:                              4573
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.653175
# Acceptance Rate:                        0.786468
# Replacements:                               3650
# Total Samples:                              4641
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.653058
# Acceptance Rate:                        0.783898
# Replacements:                               3700
# Total Samples:                              4720
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.652856
# Acceptance Rate:                        0.782881
# Replacements:                               3750
# Total Samples:                              4790
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.632584
# Acceptance Rate:                        0.781411
# Replacements:                               3800
# Total Samples:                              4863
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.631472
# Acceptance Rate:                        0.781567
# Replacements:                               3850
# Total Samples:                              4926
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.630423
# Acceptance Rate:                        0.780624
# Replacements:                               3900
# Total Samples:                              4996
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.580885
# Acceptance Rate:                        0.780787
# Replacements:                               3950
# Total Samples:                              5059
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.565511
# Acceptance Rate:                        0.778665
# Replacements:                               4000
# Total Samples:                              5137
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.489494
# Acceptance Rate:                        0.778098
# Replacements:                               4050
# Total Samples:                              5205
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.432826
# Acceptance Rate:                        0.777251
# Replacements:                               4100
# Total Samples:                              5275
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.432526
# Acceptance Rate:                        0.777590
# Replacements:                               4150
# Total Samples:                              5337
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.399322
# Acceptance Rate:                        0.778499
# Replacements:                               4200
# Total Samples:                              5395
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.399101
# Acceptance Rate:                        0.778816
# Replacements:                               4250
# Total Samples:                              5457
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.372906
# Acceptance Rate:                        0.777436
# Replacements:                               4300
# Total Samples:                              5531
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.369071
# Acceptance Rate:                        0.777619
# Replacements:                               4350
# Total Samples:                              5594
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.368853
# Acceptance Rate:                        0.776699
# Replacements:                               4400
# Total Samples:                              5665
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.348925
# Acceptance Rate:                        0.776208
# Replacements:                               4450
# Total Samples:                              5733
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.347149
# Acceptance Rate:                        0.776666
# Replacements:                               4500
# Total Samples:                              5794
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.345695
# Acceptance Rate:                        0.776186
# Replacements:                               4550
# Total Samples:                              5862
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.345282
# Acceptance Rate:                        0.776240
# Replacements:                               4600
# Total Samples:                              5926
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.345042
# Acceptance Rate:                        0.776423
# Replacements:                               4650
# Total Samples:                              5989
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.327840
# Acceptance Rate:                        0.776603
# Replacements:                               4700
# Total Samples:                              6052
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.325187
# Acceptance Rate:                        0.776778
# Replacements:                               4750
# Total Samples:                              6115
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.309069
# Acceptance Rate:                        0.776950
# Replacements:                               4800
# Total Samples:                              6178
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.291207
# Acceptance Rate:                        0.776373
# Replacements:                               4850
# Total Samples:                              6247
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.283668
# Acceptance Rate:                        0.775562
# Replacements:                               4900
# Total Samples:                              6318
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.281724
# Acceptance Rate:                        0.775376
# Replacements:                               4950
# Total Samples:                              6384
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.281464
# Acceptance Rate:                        0.775555
# Replacements:                               5000
# Total Samples:                              6447
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.268766
# Acceptance Rate:                        0.776326
# Replacements:                               5050
# Total Samples:                              6505
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.258654
# Acceptance Rate:                        0.777084
# Replacements:                               5100
# Total Samples:                              6563
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.241785
# Acceptance Rate:                        0.777828
# Replacements:                               5150
# Total Samples:                              6621
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.235717
# Acceptance Rate:                        0.777977
# Replacements:                               5200
# Total Samples:                              6684
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.226116
# Acceptance Rate:                        0.778354
# Replacements:                               5250
# Total Samples:                              6745
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.225169
# Acceptance Rate:                        0.778954
# Replacements:                               5300
# Total Samples:                              6804
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.214303
# Acceptance Rate:                        0.779883
# Replacements:                               5350
# Total Samples:                              6860
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.199064
# Acceptance Rate:                        0.780685
# Replacements:                               5400
# Total Samples:                              6917
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.188637
# Acceptance Rate:                        0.781026
# Replacements:                               5450
# Total Samples:                              6978
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.177768
# Acceptance Rate:                        0.781250
# Replacements:                               5500
# Total Samples:                              7040
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.171756
# Acceptance Rate:                        0.780810
# Replacements:                               5550
# Total Samples:                              7108
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.164233
# Acceptance Rate:                        0.780814
# Replacements:                               5600
# Total Samples:                              7172
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.158065
# Acceptance Rate:                        0.781358
# Replacements:                               5650
# Total Samples:                              7231
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.153244
# Acceptance Rate:                        0.782430
# Replacements:                               5700
# Total Samples:                              7285
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.147666
# Acceptance Rate:                        0.783272
# Replacements:                               5750
# Total Samples:                              7341
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.142292
# Acceptance Rate:                        0.784208
# Replacements:                               5800
# Total Samples:                              7396
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.138524
# Acceptance Rate:                        0.784919
# Replacements:                               5850
# Total Samples:                              7453
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.134479
# Acceptance Rate:                        0.785515
# Replacements:                               5900
# Total Samples:                              7511
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.131277
# Acceptance Rate:                        0.786205
# Replacements:                               5950
# Total Samples:                              7568
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.126755
# Acceptance Rate:                        0.786782
# Replacements:                               6000
# Total Samples:                              7626
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.122861
# Acceptance Rate:                        0.787453
# Replacements:                               6050
# Total Samples:                              7683
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.116845
# Acceptance Rate:                        0.788114
# Replacements:                               6100
# Total Samples:                              7740
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.113103
# Acceptance Rate:                        0.788462
# Replacements:                               6150
# Total Samples:                              7800
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.109957
# Acceptance Rate:                        0.789005
# Replacements:                               6200
# Total Samples:                              7858
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.105986
# Acceptance Rate:                        0.789540
# Replacements:                               6250
# Total Samples:                              7916
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.103573
# Acceptance Rate:                        0.790167
# Replacements:                               6300
# Total Samples:                              7973
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.099732
# Acceptance Rate:                        0.790883
# Replacements:                               6350
# Total Samples:                              8029
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.096498
# Acceptance Rate:                        0.791785
# Replacements:                               6400
# Total Samples:                              8083
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.094283
# Acceptance Rate:                        0.792189
# Replacements:                               6450
# Total Samples:                              8142
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.091971
# Acceptance Rate:                        0.792683
# Replacements:                               6500
# Total Samples:                              8200
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.087692
# Acceptance Rate:                        0.792403
# Replacements:                               6550
# Total Samples:                              8266
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.084789
# Acceptance Rate:                        0.792983
# Replacements:                               6600
# Total Samples:                              8323
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.082480
# Acceptance Rate:                        0.793651
# Replacements:                               6650
# Total Samples:                              8379
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.078591
# Acceptance Rate:                        0.794215
# Replacements:                               6700
# Total Samples:                              8436
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.076949
# Acceptance Rate:                        0.795147
# Replacements:                               6750
# Total Samples:                              8489
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.075509
# Acceptance Rate:                        0.795694
# Replacements:                               6800
# Total Samples:                              8546
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.073296
# Acceptance Rate:                        0.796326
# Replacements:                               6850
# Total Samples:                              8602
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.071944
# Acceptance Rate:                        0.797043
# Replacements:                               6900
# Total Samples:                              8657
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.070317
# Acceptance Rate:                        0.797842
# Replacements:                               6950
# Total Samples:                              8711
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.068221
# Acceptance Rate:                        0.798267
# Replacements:                               7000
# Total Samples:                              8769
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.066564
# Acceptance Rate:                        0.798776
# Replacements:                               7050
# Total Samples:                              8826
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.064323
# Acceptance Rate:                        0.799370
# Replacements:                               7100
# Total Samples:                              8882
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.062255
# Acceptance Rate:                        0.799866
# Replacements:                               7150
# Total Samples:                              8939
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.060040
# Acceptance Rate:                        0.800356
# Replacements:                               7200
# Total Samples:                              8996
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.058275
# Acceptance Rate:                        0.800397
# Replacements:                               7250
# Total Samples:                              9058
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.056034
# Acceptance Rate:                        0.800702
# Replacements:                               7300
# Total Samples:                              9117
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.054692
# Acceptance Rate:                        0.801352
# Replacements:                               7350
# Total Samples:                              9172
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.053149
# Acceptance Rate:                        0.801820
# Replacements:                               7400
# Total Samples:                              9229
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.051454
# Acceptance Rate:                        0.802629
# Replacements:                               7450
# Total Samples:                              9282
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.050034
# Acceptance Rate:                        0.802998
# Replacements:                               7500
# Total Samples:                              9340
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.048623
# Acceptance Rate:                        0.803021
# Replacements:                               7550
# Total Samples:                              9402
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.047003
# Acceptance Rate:                        0.803043
# Replacements:                               7600
# Total Samples:                              9464
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.045611
# Acceptance Rate:                        0.803403
# Replacements:                               7650
# Total Samples:                              9522
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.044187
# Acceptance Rate:                        0.804346
# Replacements:                               7700
# Total Samples:                              9573
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.042924
# Acceptance Rate:                        0.804693
# Replacements:                               7750
# Total Samples:                              9631
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.041619
# Acceptance Rate:                        0.805369
# Replacements:                               7800
# Total Samples:                              9685
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.040330
# Acceptance Rate:                        0.805955
# Replacements:                               7850
# Total Samples:                              9740
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.039132
# Acceptance Rate:                        0.806616
# Replacements:                               7900
# Total Samples:                              9794
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.037827
# Acceptance Rate:                        0.807352
# Replacements:                               7950
# Total Samples:                              9847
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.036658
# Acceptance Rate:                        0.807918
# Replacements:                               8000
# Total Samples:                              9902
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.035440
# Acceptance Rate:                        0.808395
# Replacements:                               8050
# Total Samples:                              9958
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.034356
# Acceptance Rate:                        0.808948
# Replacements:                               8100
# Total Samples:                             10013
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.033328
# Acceptance Rate:                        0.809656
# Replacements:                               8150
# Total Samples:                             10066
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.032397
# Acceptance Rate:                        0.810357
# Replacements:                               8200
# Total Samples:                             10119
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.031467
# Acceptance Rate:                        0.811209
# Replacements:                               8250
# Total Samples:                             10170
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.030583
# Acceptance Rate:                        0.811974
# Replacements:                               8300
# Total Samples:                             10222
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.029699
# Acceptance Rate:                        0.812652
# Replacements:                               8350
# Total Samples:                             10275
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.028863
# Acceptance Rate:                        0.813323
# Replacements:                               8400
# Total Samples:                             10328
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.028072
# Acceptance Rate:                        0.813987
# Replacements:                               8450
# Total Samples:                             10381
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.027328
# Acceptance Rate:                        0.814644
# Replacements:                               8500
# Total Samples:                             10434
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.026587
# Acceptance Rate:                        0.815528
# Replacements:                               8550
# Total Samples:                             10484
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.025921
# Acceptance Rate:                        0.816327
# Replacements:                               8600
# Total Samples:                             10535
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.025280
# Acceptance Rate:                        0.816963
# Replacements:                               8650
# Total Samples:                             10588
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.024655
# Acceptance Rate:                        0.817669
# Replacements:                               8700
# Total Samples:                             10640
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.024064
# Acceptance Rate:                        0.818139
# Replacements:                               8750
# Total Samples:                             10695
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.023466
# Acceptance Rate:                        0.818529
# Replacements:                               8800
# Total Samples:                             10751
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.022901
# Acceptance Rate:                        0.819369
# Replacements:                               8850
# Total Samples:                             10801
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.022426
# Acceptance Rate:                        0.820201
# Replacements:                               8900
# Total Samples:                             10851
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.021980
# Acceptance Rate:                        0.820724
# Replacements:                               8950
# Total Samples:                             10905
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.021540
# Acceptance Rate:                        0.821168
# Replacements:                               9000
# Total Samples:                             10960
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.021119
# Acceptance Rate:                        0.821905
# Replacements:                               9050
# Total Samples:                             11011
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.020755
# Acceptance Rate:                        0.822413
# Replacements:                               9100
# Total Samples:                             11065
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.020399
# Acceptance Rate:                        0.822990
# Replacements:                               9150
# Total Samples:                             11118
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.020077
# Acceptance Rate:                        0.823487
# Replacements:                               9200
# Total Samples:                             11172
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.019782
# Acceptance Rate:                        0.824200
# Replacements:                               9250
# Total Samples:                             11223
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.019525
# Acceptance Rate:                        0.824614
# Replacements:                               9300
# Total Samples:                             11278
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.019275
# Acceptance Rate:                        0.825170
# Replacements:                               9350
# Total Samples:                             11331
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.019057
# Acceptance Rate:                        0.825503
# Replacements:                               9400
# Total Samples:                             11387
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.018848
# Acceptance Rate:                        0.825649
# Replacements:                               9419
# Total Samples:                             11408
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.018777
#  ln(ev)=   140757170.84751579      +/-  0.30077985490747888
#  Total Likelihood Evaluations:        11408
#  Sampling finished. Exiting MultiNest

# %%
# %matplotlib inline
from chainconsumer import ChainConsumer
import numpy as np


def loadtxt2d(intext):
        try:
            return np.loadtxt(intext, ndmin=2)
        except:
            return np.loadtxt(intext)

c = ChainConsumer()

chain = loadtxt2d('./chains/1-post_equal_weights.dat')

#c.add_chain(chain, parameters=['K', 'index', 'F', 'mu','sigma', '$z$'], name='yeah')
c.add_chain(chain, parameters=['K', 'index', '$z$'], name='fit')

# %%
# c.plotter.plot(filename="fit_corner.pdf", 
#                 parameters=['K', 'index'],
#                 # truth=[6.44*10**-4, -2.08],
#                 log_scales=[]);

c.plotter.plot()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 6
#       1 # c.plotter.plot(filename="fit_corner.pdf",
#       2 #                 parameters=['K', 'index'],
#       3 #                 # truth=[6.44*10**-4, -2.08],
#       4 #                 log_scales=[]);
# ----> 6 c.plotter.plot()
#
# File ~/.pyenv/versions/3.9.13/envs/MT2/lib/python3.9/site-packages/chainconsumer/plotter.py:181, in Plotter.plot(self, figsize, parameters, chains, extents, filename, display, truth, legend, blind, watermark, log_scales)
#     178     continue
#     180 param_summary = summary and p1 not in blind
# --> 181 m = self._plot_bars(ax, p1, chain, flip=do_flip, summary=param_summary)
#     183 if max_val is None or m > max_val:
#     184     max_val = m
#
# File ~/.pyenv/versions/3.9.13/envs/MT2/lib/python3.9/site-packages/chainconsumer/plotter.py:1261, in Plotter._plot_bars(self, ax, parameter, chain, flip, summary)
#    1259     ax.fill_betweenx(x, np.zeros(x.shape), interpolator(x), color=colour, alpha=0.2, zorder=zorder)
#    1260 else:
# -> 1261     ax.fill_between(x, np.zeros(x.shape), interpolator(x), color=colour, alpha=0.2, zorder=zorder)
#    1262 if summary:
#    1263     t = self.parent.analysis.get_parameter_text(*fit_values)
#
# File ~/.pyenv/versions/3.9.13/envs/MT2/lib/python3.9/site-packages/matplotlib/__init__.py:1352, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1349 @functools.wraps(func)
#    1350 def inner(ax, *args, data=None, **kwargs):
#    1351     if data is None:
# -> 1352         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1354     bound = new_sig.bind(ax, *args, **kwargs)
#    1355     auto_label = (bound.arguments.get(label_namer)
#    1356                   or bound.kwargs.get(label_namer))
#
# File ~/.pyenv/versions/3.9.13/envs/MT2/lib/python3.9/site-packages/matplotlib/axes/_axes.py:5365, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5363 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5364                  step=None, **kwargs):
# -> 5365     return self._fill_between_x_or_y(
#    5366         "x", x, y1, y2,
#    5367         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File ~/.pyenv/versions/3.9.13/envs/MT2/lib/python3.9/site-packages/matplotlib/axes/_axes.py:5293, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5290 ind, dep1, dep2 = np.broadcast_arrays(np.atleast_1d(ind), dep1, dep2)
#    5292 polys = []
# -> 5293 for idx0, idx1 in cbook.contiguous_regions(where):
#    5294     indslice = ind[idx0:idx1]
#    5295     dep1slice = dep1[idx0:idx1]
#
# File ~/.pyenv/versions/3.9.13/envs/MT2/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1297, in contiguous_regions(mask)
#    1294     return []
#    1296 # Find the indices of region changes, and correct offset
# -> 1297 idx, = np.nonzero(mask[:-1] != mask[1:])
#    1298 idx += 1
#    1300 # List operations are faster for moderately sized arrays
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed
